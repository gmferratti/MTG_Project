# %%
import os
import requests
import zipfile
import time

# URL direta para o arquivo zip
zip_url = "https://mtgjson.com/api/v5/AllDeckFiles.zip"

# Pasta onde os arquivos serão salvos
output_folder = "decks"

# Criar a pasta se ela não existir
os.makedirs(output_folder, exist_ok=True)

# Função para baixar o arquivo zip
def download_file(url, folder):
    local_filename = os.path.join(folder, url.split("/")[-1])
    with requests.get(url, stream=True) as r:
        r.raise_for_status()
        with open(local_filename, "wb") as f:
            for chunk in r.iter_content(chunk_size=8192): 
                f.write(chunk)
    print(f"Arquivo {local_filename} baixado com sucesso!")
    return local_filename

# Baixar o arquivo zip
zip_file_path = download_file(zip_url, output_folder)

# Descompactar o arquivo zip
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(output_folder)

print(f"Todos os arquivos foram extraídos para a pasta {output_folder}.")
# Out:
# Arquivo decks\AllDeckFiles.zip baixado com sucesso!
# Todos os arquivos foram extraídos para a pasta decks.

# %%
import os
import json

# Função para carregar o JSON
def load_deck_data(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        return json.load(file)

# Função para extrair o nome do deck diretamente do JSON
def get_deck_name(data):
    return data['data'].get('name', 'Unknown Deck')  # Pega o nome do deck ou retorna 'Unknown Deck'

# Função para contar o número de cartas no mainBoard
def count_mainboard_cards(data):
    return sum(card['count'] for card in data['data']['mainBoard'])

# Função para gerar a decklist formatada
def generate_decklist(data):
    decklist = []
    deck_name = get_deck_name(data)  # Obtém o nome do deck do JSON
    decklist.append("About")
    decklist.append(f"Name {deck_name}")
    decklist.append("\nDeck")
    
    for card in data['data']['mainBoard']:
        name = card['name']
        count = card['count']
        decklist.append(f"{count} {name}")
    
    return decklist

# Função para salvar a decklist no arquivo .txt
def save_decklist(decklist, output_file):
    with open(output_file, 'w', encoding='utf-8') as file:
        file.write('\n'.join(decklist))  # Escreve tudo de uma vez para ser mais eficiente

# Função principal para processar todos os decks da pasta JSON e salvar no formato TXT
def process_all_decks(json_folder, txt_folder):
    # Criar a pasta de saída se não existir
    os.makedirs(txt_folder, exist_ok=True)
    
    # Percorrer todos os arquivos JSON na pasta
    for json_file in os.listdir(json_folder):
        if json_file.endswith('.json'):
            json_file_path = os.path.join(json_folder, json_file)
            
            # Carregar o arquivo JSON
            data = load_deck_data(json_file_path)
            
            # Verificar se o deck tem pelo menos 40 cartas no mainBoard
            if count_mainboard_cards(data) >= 40:
                # Gerar a decklist
                decklist = generate_decklist(data)
                
                # Definir o nome do arquivo de saída .txt com base no nome do deck
                deck_name = get_deck_name(data)
                output_file_name = f"{deck_name.replace(' ', '_')}.txt"
                output_file_path = os.path.join(txt_folder, output_file_name)
                
                # Salvar a decklist no formato .txt
                save_decklist(decklist, output_file_path)
                print(f"Decklist {output_file_name} gerada com sucesso!")
            else:
                print(f"Deck {json_file} ignorado (menos de 40 cartas no mainBoard).")

# Exemplo de uso
json_folder = "decks"  # Pasta onde os arquivos JSON estão localizados
txt_folder = "decks_txt"  # Pasta onde os arquivos .txt serão salvos

process_all_decks(json_folder, txt_folder)
# Out:
# Deck 2014FullArtLandSet_J14.json ignorado (menos de 40 cartas no mainBoard).
# Deck 30ThAnniversaryCountdownKit_SLC.json ignorado (menos de 40 cartas no mainBoard).
# Deck AboveTheClouds1_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck AboveTheClouds2_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck AboveTheClouds3_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck AboveTheClouds4_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck ABoxOfRocksFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ABoxOfRocks_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck AbsoluteAnnihilationFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck AbsoluteAnnihilation_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Abzan_Siege.txt gerada com sucesso!
# Decklist Adaptive_Enchantment.txt gerada com sucesso!
# Deck AdventuresInTheForgottenRealmsWelcomeBooster_AFR.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Aeo_Paquette_-_Affinity.txt gerada com sucesso!
# Decklist Aerial_Acrobatics.txt gerada com sucesso!
# Decklist Aerial_Domination.txt gerada com sucesso!
# Decklist Aerodoom.txt gerada com sucesso!
# Decklist Ahoy_Mateys.txt gerada com sucesso!
# Decklist Air_Forces.txt gerada com sucesso!
# Decklist Air_Razers.txt gerada com sucesso!
# Decklist Ajani_Goldmane.txt gerada com sucesso!
# Decklist Ajani,_Inspiring_Leader.txt gerada com sucesso!
# Decklist Ajani,_Valiant_Protector.txt gerada com sucesso!
# Decklist Ajani.txt gerada com sucesso!
# Decklist Alex_Borteh_-_Merfolk_Opposition.txt gerada com sucesso!
# Decklist Allied_Fires.txt gerada com sucesso!
# Deck AmonkhetWelcomeDeckBlack_W17.json ignorado (menos de 40 cartas no mainBoard).
# Deck AmonkhetWelcomeDeckBlue_W17.json ignorado (menos de 40 cartas no mainBoard).
# Deck AmonkhetWelcomeDeckGreen_W17.json ignorado (menos de 40 cartas no mainBoard).
# Deck AmonkhetWelcomeDeckRed_W17.json ignorado (menos de 40 cartas no mainBoard).
# Deck AmonkhetWelcomeDeckWhite_W17.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Ancient_Arsenal.txt gerada com sucesso!
# Decklist Ancient_Discovery.txt gerada com sucesso!
# Decklist Angelic_Accountants.txt gerada com sucesso!
# Decklist Angelic_Army_2.txt gerada com sucesso!
# Decklist Angelic_Army.txt gerada com sucesso!
# Decklist Angelic_Fury.txt gerada com sucesso!
# Decklist Angelic_Might.txt gerada com sucesso!
# Deck Angels1_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Angels2_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Angels_They're_Just_Like_Us_but_Cooler_and_with_Wings.txt gerada com sucesso!
# Decklist Angrath,_Minotaur_Pirate.txt gerada com sucesso!
# Decklist Animated_Army.txt gerada com sucesso!
# Decklist Anthology_Planes_Deck.txt gerada com sucesso!
# Decklist Anthousa's_Army.txt gerada com sucesso!
# Decklist Antoine_Ruel_-_Blue-Black-Red_Nether-Go.txt gerada com sucesso!
# Decklist Ape_Lord.txt gerada com sucesso!
# Deck AprilFoolsFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck AragornAtHelmsDeep_LTC.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Arcane_Aggression.txt gerada com sucesso!
# Deck ArcaneFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Arcane_Inventions.txt gerada com sucesso!
# Deck ArcaneLandsFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArcaneLands_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Arcane_Maelstrom.txt gerada com sucesso!
# Deck ArcaneMischief_DMU.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Arcane_Tempo.txt gerada com sucesso!
# Decklist Arcane_Wizardry.txt gerada com sucesso!
# Deck Arcane_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Arcanis's_Guile.txt gerada com sucesso!
# Deck Archaeology1_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Archaeology2_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Archaeology3_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Archaeology4_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Arch_Angel.txt gerada com sucesso!
# Decklist Archenemy_Nicol_Bolas.txt gerada com sucesso!
# Decklist Armada.txt gerada com sucesso!
# Decklist Armed_and_Dangerous.txt gerada com sucesso!
# Decklist Armed_and_Dangerous.txt gerada com sucesso!
# Decklist Armed.txt gerada com sucesso!
# Decklist Arm_for_Battle.txt gerada com sucesso!
# Decklist Army_of_Entropy.txt gerada com sucesso!
# Decklist Army_of_Justice.txt gerada com sucesso!
# Decklist Artful_Destruction.txt gerada com sucesso!
# Decklist Artifacts_Attack.txt gerada com sucesso!
# Deck ArtistSeriesAlaynaDannerFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesAlaynaDanner_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesAleksiBriclotFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesAleksiBriclot_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesChrisRahnFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesChrisRahn_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesJohannesVossFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesJohannesVoss_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesJohnAvonFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesJohnAvon_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesKevWalkerFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesKevWalker_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesLiviaPrimaFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesLiviaPrima_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesMagaliVilleneuveFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesMagaliVilleneuve_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesMarkPooleFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesMarkPoole_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesNilsHammFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesNilsHamm_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesRandyVargasFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesRandyVargas_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesRebeccaGuayFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesRebeccaGuay_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesRyanAlexanderLeeFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesRyanAlexanderLee_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesSamBurleyFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesSamBurley_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesSebMckinnonFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesSebMckinnon_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesSidharthChaturvediFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesSidharthChaturvedi_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesThomasBaxaFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesThomasBaxa_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesVictorAdameMinguezFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesVictorAdameMinguez_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesVolkanBagaFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesVolkanBaga_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesWayneReynoldsFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ArtistSeriesWayneReynolds_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Arzakon.txt gerada com sucesso!
# Decklist Ashiok.txt gerada com sucesso!
# Decklist Assassin_-_Enhanced_Deck.txt gerada com sucesso!
# Decklist Assassin.txt gerada com sucesso!
# Decklist Assemble_The_Doomsday_Machine.txt gerada com sucesso!
# Decklist Assemble_Victory.txt gerada com sucesso!
# Decklist Astral_Visionary.txt gerada com sucesso!
# Decklist Aura_Mastery.txt gerada com sucesso!
# Decklist Aura_of_Courage.txt gerada com sucesso!
# Decklist Auras_of_Majesty.txt gerada com sucesso!
# Decklist Aurochs_Stampede.txt gerada com sucesso!
# Decklist Avalanche!.txt gerada com sucesso!
# Decklist Awakening_Earth.txt gerada com sucesso!
# Decklist Azaar_Lichlord.txt gerada com sucesso!
# Decklist Azorius_Advance.txt gerada com sucesso!
# Decklist Azorius_Ascendant.txt gerada com sucesso!
# Decklist Azorius_Ascension.txt gerada com sucesso!
# Decklist Azorius_Authority.txt gerada com sucesso!
# Decklist Azorius_Control.txt gerada com sucesso!
# Deck AzoriusSenate1_CLU.json ignorado (menos de 40 cartas no mainBoard).
# Deck AzoriusSenate2_CLU.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Azorius_Senate.txt gerada com sucesso!
# Decklist Azorius_Spirits.txt gerada com sucesso!
# Decklist Azorius.txt gerada com sucesso!
# Decklist Azure_Skies_2.txt gerada com sucesso!
# Decklist Azure_Skies.txt gerada com sucesso!
# Decklist Back_for_More.txt gerada com sucesso!
# Decklist Backup_Beatdown.txt gerada com sucesso!
# Deck BadToTheBonesFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck BadToTheBones_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Bait_and_Bludgeon.txt gerada com sucesso!
# Decklist Bait_&_Switch.txt gerada com sucesso!
# Decklist Balance_in_All_Things.txt gerada com sucesso!
# Decklist Band_Together.txt gerada com sucesso!
# Decklist Bant_Exalted.txt gerada com sucesso!
# Decklist Bant_on_the_March.txt gerada com sucesso!
# Decklist Barrage.txt gerada com sucesso!
# Decklist Basri,_Devoted_Paladin.txt gerada com sucesso!
# Deck Basri_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Battalion.txt gerada com sucesso!
# Decklist Battle_Blitz.txt gerada com sucesso!
# Decklist Battle_Cries.txt gerada com sucesso!
# Deck BattleCry_MBS.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Battle_Surge_-_Enhanced_Deck.txt gerada com sucesso!
# Decklist Battle_Surge.txt gerada com sucesso!
# Decklist Beast_Master.txt gerada com sucesso!
# Deck BeastTerritory_DMU.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Bedecked_Brokers.txt gerada com sucesso!
# Decklist Ben_Rubin_-_Sligh.txt gerada com sucesso!
# Decklist Bertrand_Lestree,_Finalist.txt gerada com sucesso!
# Decklist Bestial_Strength.txt gerada com sucesso!
# Decklist Beyond_The_Grave.txt gerada com sucesso!
# Deck BitterblossomDreams_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlackAndGreenDelirium_KLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlackAndRedMadness_KLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlackAndWhiteVampires_XLN.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlackDeckA_10E.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlackDeckA_M11.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlackDeckA_M12.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlackDeckB_10E.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlackDeckB_M11.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlackDeckB_M12.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlackDeck_M14.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlackDeck_M20.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlackDeck_ORI.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlackDeck_W16.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlackDevotion_M15.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlackDiscard_MBS.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Black-Green_Deck.txt gerada com sucesso!
# Deck BlackGreenGraveyard_M15.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlackIsMagicFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlackIsMagic_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlackRedDestruction_ROE.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlackRedMinotaurs_M15.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlackSampleDeck_M13.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlackSampleDeck_M15.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Black.txt gerada com sucesso!
# Deck Black_UND.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Blades_of_Victory.txt gerada com sucesso!
# Decklist Blame_Game.txt gerada com sucesso!
# Decklist Blast_from_the_Past.txt gerada com sucesso!
# Decklist Blazing_Beasts_of_Myth.txt gerada com sucesso!
# Decklist Blessed.txt gerada com sucesso!
# Decklist Blinding_Fury.txt gerada com sucesso!
# Deck Blink1_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Blink2_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Blink3_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Blink4_J22.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Blood_and_Fire.txt gerada com sucesso!
# Deck BloodBowlFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck BloodBowl_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Blood_Rites.txt gerada com sucesso!
# Decklist Blossoming_Growth.txt gerada com sucesso!
# Decklist Blowout.txt gerada com sucesso!
# Deck BlueAndBlackPirates_XLN.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlueAndBlackZombies_KLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlueAndColorlessArtifacts_KLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlueAndGreenMerfolk_XLN.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlueAndGreenRamp_XLN.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlueAndGreen_KLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlueAndWhiteFlying_KLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlueControl_ROE.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlueDeckA_10E.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlueDeckA_M11.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlueDeckA_M12.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlueDeckB_10E.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlueDeckB_M11.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlueDeckB_M12.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlueDeck_M14.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlueDeck_M20.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlueDeck_ORI.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlueDeck_W16.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlueGreenEntersTheBattlefield_M15.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlueRedArtifacts_M15.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlueRedCounterburn_M15.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlueSampleDeck_M13.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlueSampleDeck_M15.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlueWhiteFliers_ROE.json ignorado (menos de 40 cartas no mainBoard).
# Deck BlueWhiteFlyers_MBS.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Blue.txt gerada com sucesso!
# Deck Blue_UND.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Boggart_Feast.txt gerada com sucesso!
# Decklist Boltslinger.txt gerada com sucesso!
# Decklist Bomber.txt gerada com sucesso!
# Deck Boneyard1_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Boneyard2_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck BoosterBattlePackBoros_GTC.json ignorado (menos de 40 cartas no mainBoard).
# Deck BoosterBattlePackDimir_GTC.json ignorado (menos de 40 cartas no mainBoard).
# Deck BoosterBattlePackGruul_GTC.json ignorado (menos de 40 cartas no mainBoard).
# Deck BoosterBattlePackOrzhov_GTC.json ignorado (menos de 40 cartas no mainBoard).
# Deck BoosterBattlePackSimic_GTC.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Boros_Assault.txt gerada com sucesso!
# Decklist Boros_Battalion.txt gerada com sucesso!
# Deck BorosLegion1_CLU.json ignorado (menos de 40 cartas no mainBoard).
# Deck BorosLegion2_CLU.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Boros_Legion.txt gerada com sucesso!
# Decklist Boros.txt gerada com sucesso!
# Decklist Bound_by_Strength.txt gerada com sucesso!
# Decklist Boundless_Elves.txt gerada com sucesso!
# Decklist Braaains.txt gerada com sucesso!
# Decklist Brave_the_Battle.txt gerada com sucesso!
# Decklist Brazen_Coalition.txt gerada com sucesso!
# Decklist Breakdown_-_Enhanced_Deck.txt gerada com sucesso!
# Decklist Breakdown.txt gerada com sucesso!
# Decklist Breath_of_Fire.txt gerada com sucesso!
# Decklist Breed_Lethality.txt gerada com sucesso!
# Decklist Breed_Lethality.txt gerada com sucesso!
# Decklist Brian_Hacker_-_White_Weenie.txt gerada com sucesso!
# Decklist Brian_Kibler_-_Red_Zone_2K2.txt gerada com sucesso!
# Decklist Brian_Selden_-_Cali_Nightmare.txt gerada com sucesso!
# Decklist Bring_About_The_Undead_Apocalypse.txt gerada com sucesso!
# Deck Brood1_MOM.json ignorado (menos de 40 cartas no mainBoard).
# Deck Brood2_MOM.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Brotherhood_Agents.txt gerada com sucesso!
# Decklist Brute_Force.txt gerada com sucesso!
# Decklist Buckle_Up.txt gerada com sucesso!
# Deck Buff1_MOM.json ignorado (menos de 40 cartas no mainBoard).
# Deck Buff2_MOM.json ignorado (menos de 40 cartas no mainBoard).
# Deck BugginOutFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck BugginOut_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Built_From_Scratch.txt gerada com sucesso!
# Decklist Built_From_Scratch.txt gerada com sucesso!
# Decklist Burial.txt gerada com sucesso!
# Deck BurningRevelations_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Burning_Sky.txt gerada com sucesso!
# Decklist Cabaretti_Cacophony.txt gerada com sucesso!
# Decklist Call_for_Backup.txt gerada com sucesso!
# Deck CallingAllHydraHeadsFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Call_of_Blood.txt gerada com sucesso!
# Decklist Call_of_the_Kor_-_Advanced_Deck.txt gerada com sucesso!
# Decklist Call_of_the_Kor.txt gerada com sucesso!
# Decklist Call_the_Spirits.txt gerada com sucesso!
# Deck CanYouFeelWithAHeartOfSteelFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Carlos_Romão_-_Psychatog.txt gerada com sucesso!
# Decklist Carnival_of_Blood.txt gerada com sucesso!
# Deck Cats1_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Cats1_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Cats2_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Cats2_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Cats3_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Cats4_J22.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Cavalcade_Charge.txt gerada com sucesso!
# Decklist Cavalry_Charge.txt gerada com sucesso!
# Decklist Celestial_Assault.txt gerada com sucesso!
# Decklist Chandra,_Bold_Pyromancer.txt gerada com sucesso!
# Decklist Chandra,_Flame's_Catalyst.txt gerada com sucesso!
# Decklist Chandra,_Flame's_Fury.txt gerada com sucesso!
# Decklist Chandra_Japanese.txt gerada com sucesso!
# Decklist Chandra,_Pyrogenius.txt gerada com sucesso!
# Decklist Chandra.txt gerada com sucesso!
# Decklist Chandra.txt gerada com sucesso!
# Deck Chandra_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Chandra.txt gerada com sucesso!
# Decklist Chaos_and_Mayhem.txt gerada com sucesso!
# Decklist Chaos_Incarnate.txt gerada com sucesso!
# Decklist Chaos_Reigns.txt gerada com sucesso!
# Decklist Chaos_Reigns.txt gerada com sucesso!
# Decklist Charge_of_the_Boros.txt gerada com sucesso!
# Decklist Charging_Ahead.txt gerada com sucesso!
# Decklist Chargoyf.txt gerada com sucesso!
# Decklist Cho-Manno's_Resolve.txt gerada com sucesso!
# Decklist Cinder_Heart.txt gerada com sucesso!
# Deck CityStylesFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck CityStyles_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Cleric.txt gerada com sucesso!
# Deck ClueEditionCoreContents_CLU.json ignorado (menos de 40 cartas no mainBoard).
# Deck CoalitionCorps_DMU.json ignorado (menos de 40 cartas no mainBoard).
# Deck CoalitionLegion_DMU.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Code_of_the_Orzhov.txt gerada com sucesso!
# Decklist Cold-Blooded_Killers.txt gerada com sucesso!
# Decklist Collateral_Damage.txt gerada com sucesso!
# Decklist Collectors'_Edition.txt gerada com sucesso!
# Decklist Comeback.txt gerada com sucesso!
# Deck CommanderCollectionBlackPremium_CC2.json ignorado (menos de 40 cartas no mainBoard).
# Deck CommanderCollectionBlack_CC2.json ignorado (menos de 40 cartas no mainBoard).
# Deck CommanderCollectionGreenPremium_CC1.json ignorado (menos de 40 cartas no mainBoard).
# Deck CommanderCollectionGreen_CC1.json ignorado (menos de 40 cartas no mainBoard).
# Deck CommanderSArsenalOversized_OCM1.json ignorado (menos de 40 cartas no mainBoard).
# Deck CommanderSArsenal_CM1.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Company_of_Knights.txt gerada com sucesso!
# Decklist Concerted_Effort.txt gerada com sucesso!
# Decklist Conjurer.txt gerada com sucesso!
# Decklist Conquering_Hordes.txt gerada com sucesso!
# Deck Constellation1_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Constellation2_J22.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Control_Center.txt gerada com sucesso!
# Deck CoolOceanBreezeFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck CoolOceanBreeze_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck Core2019WelcomeDeckBlack_M19.json ignorado (menos de 40 cartas no mainBoard).
# Deck Core2019WelcomeDeckBlue_M19.json ignorado (menos de 40 cartas no mainBoard).
# Deck Core2019WelcomeDeckGreen_M19.json ignorado (menos de 40 cartas no mainBoard).
# Deck Core2019WelcomeDeckRed_M19.json ignorado (menos de 40 cartas no mainBoard).
# Deck Core2019WelcomeDeckWhite_M19.json ignorado (menos de 40 cartas no mainBoard).
# Deck CoreSet2021WelcomeBooster_M21.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Corrupting_Influence.txt gerada com sucesso!
# Deck Corruption1_ONE.json ignorado (menos de 40 cartas no mainBoard).
# Deck Corruption2_ONE.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Counterpunch.txt gerada com sucesso!
# Decklist Counter_Surge.txt gerada com sucesso!
# Deck Courageous1_LTR.json ignorado (menos de 40 cartas no mainBoard).
# Deck Courageous2_LTR.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Coven_Counters.txt gerada com sucesso!
# Decklist Crack_the_Case.txt gerada com sucesso!
# Decklist Creative_Energy_Collector's_Edition.txt gerada com sucesso!
# Decklist Creative_Energy.txt gerada com sucesso!
# Decklist Creep_and_Conquer.txt gerada com sucesso!
# Deck CreepshowFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck Creepshow_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Critical_Mass.txt gerada com sucesso!
# Decklist Critter_Corps.txt gerada com sucesso!
# Deck CrocodileJacksonsMonstrousMenagerieEtched_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck CrocodileJacksonsMonstrousMenagerie_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck Cruel1_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Cruel2_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Cruel3_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Cruel4_J22.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Cruel_Plots.txt gerada com sucesso!
# Decklist Crusader.txt gerada com sucesso!
# Decklist Crusher_-_Enhanced_Deck.txt gerada com sucesso!
# Decklist Crusher.txt gerada com sucesso!
# Deck CultOfRakdos1_CLU.json ignorado (menos de 40 cartas no mainBoard).
# Deck CultOfRakdos2_CLU.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Cult_of_Rakdos.txt gerada com sucesso!
# Deck CultureShocksBant_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck CultureShocksEsper_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck CultureShocksGrixis_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck CultureShocksJund_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck CultureShocksNaya_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck Cunning1_LTR.json ignorado (menos de 40 cartas no mainBoard).
# Deck Cunning2_LTR.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Cunning_Plan.txt gerada com sucesso!
# Decklist Cunning.txt gerada com sucesso!
# Decklist Cursed.txt gerada com sucesso!
# Decklist Custom_Creatures.txt gerada com sucesso!
# Deck Cycling1_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Cycling2_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck DanFrazierIsBackAgainTheAlliedTalismansEtched_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck DanFrazierIsBackAgainTheAlliedTalismans_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck DanFrazierIsBackAgainTheEnemyTalismansEtched_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck DanFrazierIsBackAgainTheEnemyTalismans_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck DanFrazierIsBackTheAlliedSignetsEtched_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck DanFrazierIsBackTheAlliedSignets_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck DanFrazierIsBackTheEnemySignetsEtched_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck DanFrazierIsBackTheEnemySignets_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck DanFrazierSMoxBox_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Dangerous_Knowledge.txt gerada com sucesso!
# Decklist Dangerous.txt gerada com sucesso!
# Decklist Daniel_Zink_-_White-Blue-Green_Wake.txt gerada com sucesso!
# Decklist Dark_Alliance.txt gerada com sucesso!
# Decklist Dark_Devotion.txt gerada com sucesso!
# Decklist Dark_Sacrifice.txt gerada com sucesso!
# Decklist Dark_Sacrifice.txt gerada com sucesso!
# Decklist Dave_Humpherys_-_Blue-Green_Madness.txt gerada com sucesso!
# Decklist Day_of_the_Dragon.txt gerada com sucesso!
# Deck DdHonorAmongThievesFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck DdHonorAmongThieves_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Dead_Again.txt gerada com sucesso!
# Decklist Dead_Ahead.txt gerada com sucesso!
# Decklist Dead_and_Alive.txt gerada com sucesso!
# Decklist Deadly_Discovery.txt gerada com sucesso!
# Decklist Deadly_Disguise.txt gerada com sucesso!
# Decklist Deadly_Instinct.txt gerada com sucesso!
# Decklist Deadspread.txt gerada com sucesso!
# Decklist Deathbreed.txt gerada com sucesso!
# Decklist Deathdancer_Xira.txt gerada com sucesso!
# Decklist Deathfed.txt gerada com sucesso!
# Deck DeathIsTemporaryMetalIsForeverFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck DeathIsTemporaryMetalIsForever_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Deathly_Dominion.txt gerada com sucesso!
# Decklist Death_March.txt gerada com sucesso!
# Decklist Death_Reaper.txt gerada com sucesso!
# Decklist Death's_Beginning.txt gerada com sucesso!
# Decklist Death's_Encroach.txt gerada com sucesso!
# Decklist Death's_Minions.txt gerada com sucesso!
# Decklist Decay.txt gerada com sucesso!
# Deck DeckA_5ED.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Deck_A.txt gerada com sucesso!
# Decklist Deck_Builder's_Toolkit_Fixed_Content.txt gerada com sucesso!
# Decklist Deck_Builder's_Toolkit_Fixed_Content.txt gerada com sucesso!
# Decklist Deck_Builder's_Toolkit.txt gerada com sucesso!
# Decklist Deck_Builder's_Toolkit.txt gerada com sucesso!
# Deck DeckB_5ED.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Deck_B.txt gerada com sucesso!
# Decklist Deep_Clue_Sea.txt gerada com sucesso!
# Decklist Deep_Freeze_-_Advanced_Deck.txt gerada com sucesso!
# Decklist Deep_Freeze.txt gerada com sucesso!
# Decklist Deepwood_Menace_-_Enhanced_Deck.txt gerada com sucesso!
# Decklist Deepwood_Menace.txt gerada com sucesso!
# Decklist Defenders_of_the_Cause.txt gerada com sucesso!
# Deck DemoBoosterPlayer1_9ED.json ignorado (menos de 40 cartas no mainBoard).
# Deck DemoBoosterPlayer2_9ED.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Demonic_Deals.txt gerada com sucesso!
# Decklist Demonic.txt gerada com sucesso!
# Decklist Demonic.txt gerada com sucesso!
# Deck Demons1_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Demons2_J22.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Depths_of_Power.txt gerada com sucesso!
# Decklist Desert_Bloom.txt gerada com sucesso!
# Decklist Desert_Oasis.txt gerada com sucesso!
# Decklist Desperate_Stand.txt gerada com sucesso!
# Decklist Destructive_Firepower.txt gerada com sucesso!
# Deck Detective1_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Detective2_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Detective3_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Detective4_J22.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Devastation.txt gerada com sucesso!
# Deck Devilish1_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Devilish2_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Devilish3_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Devilish4_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Devotion_to_Darkness.txt gerada com sucesso!
# Decklist Devour_for_Power.txt gerada com sucesso!
# Decklist Devour_for_Power.txt gerada com sucesso!
# Decklist Devouring_Skies.txt gerada com sucesso!
# Decklist Dimir_Control.txt gerada com sucesso!
# Decklist Dimir_Control.txt gerada com sucesso!
# Decklist Dimir_Dementia.txt gerada com sucesso!
# Decklist Dimir_Intrigues.txt gerada com sucesso!
# Decklist Dimir_Manipulation.txt gerada com sucesso!
# Decklist Dimir_Rogue.txt gerada com sucesso!
# Decklist Dimir.txt gerada com sucesso!
# Decklist Dino_Might.txt gerada com sucesso!
# Deck Dinosaurs1_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Dinosaurs2_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Dinosaurs3_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Dinosaurs4_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Discarding1_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Discarding2_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Dismissal.txt gerada com sucesso!
# Decklist Disrupter_-_Enhanced_Deck.txt gerada com sucesso!
# Decklist Disrupter.txt gerada com sucesso!
# Decklist Distress.txt gerada com sucesso!
# Decklist Divine_Convocation.txt gerada com sucesso!
# Decklist Divine.txt gerada com sucesso!
# Decklist Divine.txt gerada com sucesso!
# Deck Doctor1_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Doctor2_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Doctor3_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Doctor4_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck DoctorWhoRegenerationFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck DoctorWhoRegeneration_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck DoctorWhoTheDalekLandsFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck DoctorWhoTheDalekLands_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck DoctorWhoTheWeepingAngelsFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck DoctorWhoTheWeepingAngels_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck Dogs1_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Dogs2_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Domain.txt gerada com sucesso!
# Decklist Dome_Destruction.txt gerada com sucesso!
# Deck DominariaUnitedWelcomeBooster_DMU.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Dominator_-_Advanced_Deck.txt gerada com sucesso!
# Decklist Dominator_-_Basic_Deck.txt gerada com sucesso!
# Decklist Domri,_City_Smasher.txt gerada com sucesso!
# Decklist Doom_Inevitable.txt gerada com sucesso!
# Decklist Dovin,_Architect_of_Law.txt gerada com sucesso!
# Decklist Draconic_Destruction.txt gerada com sucesso!
# Decklist Draconic_Dissent.txt gerada com sucesso!
# Decklist Draconic_Domination.txt gerada com sucesso!
# Decklist Draconic_Fury.txt gerada com sucesso!
# Decklist Draconic_Fury.txt gerada com sucesso!
# Decklist Draconic_Rage.txt gerada com sucesso!
# Deck Dragons1_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Dragons1_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Dragons2_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Dragons2_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Dragon's_Fire.txt gerada com sucesso!
# Decklist Dragons.txt gerada com sucesso!
# Deck DrawYourHandFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck DrawYourHand_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Druid.txt gerada com sucesso!
# Decklist Dungeon_Delving.txt gerada com sucesso!
# Decklist Dungeons_of_Death.txt gerada com sucesso!
# Decklist Ears_of_the_Elves.txt gerada com sucesso!
# Decklist Earth_Shakers.txt gerada com sucesso!
# Deck EldraineWonderlandFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Eldrazi_Arisen.txt gerada com sucesso!
# Decklist Eldrazi_Assault.txt gerada com sucesso!
# Decklist Eldrazi_Incursion_Collector's_Edition.txt gerada com sucesso!
# Decklist Eldrazi_Incursion.txt gerada com sucesso!
# Decklist Eldrazi_Unbound.txt gerada com sucesso!
# Decklist Eldrazi.txt gerada com sucesso!
# Deck Eldrazi_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Eldrazi_ROE.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Eldritch_Onslaught.txt gerada com sucesso!
# Decklist Elementals'_Path.txt gerada com sucesso!
# Decklist Elemental_Thunder.txt gerada com sucesso!
# Decklist Elspeth.txt gerada com sucesso!
# Decklist Elspeth.txt gerada com sucesso!
# Decklist Elspeth.txt gerada com sucesso!
# Deck Elven1_LTR.json ignorado (menos de 40 cartas no mainBoard).
# Deck Elven2_LTR.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Elven_Council.txt gerada com sucesso!
# Decklist Elven_Empire.txt gerada com sucesso!
# Deck Elves1_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Elves1_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Elves2_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Elves2_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Elves3_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Elves4_J22.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Elves.txt gerada com sucesso!
# Decklist Elves.txt gerada com sucesso!
# Deck Elves_MBS.json ignorado (menos de 40 cartas no mainBoard).
# Deck Elves_ROE.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Elvish_Magi.txt gerada com sucesso!
# Decklist Elvish_Predation.txt gerada com sucesso!
# Decklist Elvish_Rage.txt gerada com sucesso!
# Deck Enchanted1_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Enchanted2_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Enchanter_-_Enhanced_Deck.txt gerada com sucesso!
# Decklist Enchanter.txt gerada com sucesso!
# Decklist Enchantress_Rubinia.txt gerada com sucesso!
# Decklist Enchantress.txt gerada com sucesso!
# Decklist Endless_Hordes.txt gerada com sucesso!
# Decklist Endless_March.txt gerada com sucesso!
# Decklist Enduring_Enchantments.txt gerada com sucesso!
# Decklist Enhanced_Evolution.txt gerada com sucesso!
# Decklist Enlightened_Mastery.txt gerada com sucesso!
# Decklist Entangling_Webs.txt gerada com sucesso!
# Decklist Entropic_Uprising.txt gerada com sucesso!
# Decklist Eric_Tam,_Quarterfinalist.txt gerada com sucesso!
# Decklist Eruption_-_Enhanced_Deck.txt gerada com sucesso!
# Decklist Eruption.txt gerada com sucesso!
# Decklist Esper_Air_Assault.txt gerada com sucesso!
# Decklist Esper_Artifice.txt gerada com sucesso!
# Decklist Eternal_Bargain.txt gerada com sucesso!
# Decklist Eternal_Siege.txt gerada com sucesso!
# Decklist Eternal_Thirst.txt gerada com sucesso!
# Decklist Evasive_Maneuvers.txt gerada com sucesso!
# Decklist Evasive_Maneuvers.txt gerada com sucesso!
# Deck EveryDogHasItsDayFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck EveryDogHasItsDay_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck EvilDeadFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck EvilDead_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Evincar's_Tyranny.txt gerada com sucesso!
# Decklist Exiler.txt gerada com sucesso!
# Decklist Exit_from_Exile.txt gerada com sucesso!
# Deck Expendable1_MOM.json ignorado (menos de 40 cartas no mainBoard).
# Deck Expendable2_MOM.json ignorado (menos de 40 cartas no mainBoard).
# Deck Experimental1_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Experimental2_J22.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Explorers_of_the_Deep.txt gerada com sucesso!
# Deck ExplosionSounds_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Expulsion.txt gerada com sucesso!
# Decklist Exquisite_Invention.txt gerada com sucesso!
# Deck ExtraLife2020Foil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ExtraLife2021Foil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ExtraLife2021_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ExtraLife2022Foil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ExtraLife2022_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Eyes_of_Shadow.txt gerada com sucesso!
# Decklist Faceless_Menace.txt gerada com sucesso!
# Decklist Fae_Dominion.txt gerada com sucesso!
# Deck FaerieFaerieFaerieRadFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Faerie_Pranks.txt gerada com sucesso!
# Deck Faeries1_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Faeries2_J22.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Faerie_Schemes.txt gerada com sucesso!
# Decklist Family_Matters.txt gerada com sucesso!
# Deck Fangs1_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Fangs2_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Fangs3_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Fangs4_J22.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Fangs_of_the_Bloodchief.txt gerada com sucesso!
# Deck FarOutManFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck FarOutMan_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Fate_and_Fury.txt gerada com sucesso!
# Decklist Fate_Blaster.txt gerada com sucesso!
# Decklist Fates_Foreseen.txt gerada com sucesso!
# Decklist Fate.txt gerada com sucesso!
# Decklist Favors_From_Nyx.txt gerada com sucesso!
# Deck FblthpCompletelyUtterlyTotallyLostFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck FblthpCompletelyUtterlyTotallyLost_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Feast_of_Flesh.txt gerada com sucesso!
# Deck FeatheredFriends1_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck FeatheredFriends2_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck FeatheredFriends3_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck FeatheredFriends4_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck FeaturingGaryBasemanFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck FeaturingGaryBaseman_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck FeaturingTheMountainGoatsFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck FeaturingTheMountainGoats_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Feline_Ferocity.txt gerada com sucesso!
# Deck Ferocious1_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Ferocious2_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Ferocious3_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Ferocious4_J22.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Fiendish_Nature_-_Enhanced_Deck.txt gerada com sucesso!
# Decklist Fiendish_Nature.txt gerada com sucesso!
# Deck Fiery1_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Fiery2_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Fiery3_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Fiery4_J22.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Fiery_Dawn.txt gerada com sucesso!
# Decklist Fiery_Fury.txt gerada com sucesso!
# Decklist Final_Adventure.txt gerada com sucesso!
# Deck FinallyLefthandedMagicCardsFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck FinallyLefthandedMagicCards_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Finkel.txt gerada com sucesso!
# Decklist Fire_and_Lightning.txt gerada com sucesso!
# Decklist Firebomber.txt gerada com sucesso!
# Decklist Fire_Surge.txt gerada com sucesso!
# Decklist Fireworks.txt gerada com sucesso!
# Decklist First_Flight.txt gerada com sucesso!
# Deck FirstSeries_PVAN.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Fixed_Content.txt gerada com sucesso!
# Decklist Fixed_Content.txt gerada com sucesso!
# Decklist Fixed_Content.txt gerada com sucesso!
# Decklist Flames_of_Rath_-_Advanced_Deck.txt gerada com sucesso!
# Decklist Flames_Of_The_Dragon.txt gerada com sucesso!
# Decklist Flash_of_Ferocity.txt gerada com sucesso!
# Decklist Flashy_Fliers.txt gerada com sucesso!
# Deck FlightOfTheWitchKing_LTC.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Flyover.txt gerada com sucesso!
# Decklist Food_and_Fellowship.txt gerada com sucesso!
# Decklist Forces_of_the_Imperium_Collector's_Edition.txt gerada com sucesso!
# Decklist Forces_of_the_Imperium.txt gerada com sucesso!
# Decklist Forest_Dragon.txt gerada com sucesso!
# Decklist Forest's_Might_2.txt gerada com sucesso!
# Decklist Forest's_Might.txt gerada com sucesso!
# Decklist Forest's_Might.txt gerada com sucesso!
# Decklist Forged_in_Battle.txt gerada com sucesso!
# Decklist Forged_In_Stone.txt gerada com sucesso!
# Deck FortniteFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck FortniteLandmarksAndLocationsFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck FortniteLandmarksAndLocations_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck Fortnite_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck FourthSeries_PVAN.json ignorado (menos de 40 cartas no mainBoard).
# Decklist From_Cute_to_Brute.txt gerada com sucesso!
# Deck FromTheVaultAngels_V15.json ignorado (menos de 40 cartas no mainBoard).
# Deck FromTheVaultAnnihilation_V14.json ignorado (menos de 40 cartas no mainBoard).
# Deck FromTheVaultDragons_DRB.json ignorado (menos de 40 cartas no mainBoard).
# Deck FromTheVaultExiled_V09.json ignorado (menos de 40 cartas no mainBoard).
# Deck FromTheVaultLegends_V11.json ignorado (menos de 40 cartas no mainBoard).
# Deck FromTheVaultLore_V16.json ignorado (menos de 40 cartas no mainBoard).
# Deck FromTheVaultRealms_V12.json ignorado (menos de 40 cartas no mainBoard).
# Deck FromTheVaultRelics_V10.json ignorado (menos de 40 cartas no mainBoard).
# Deck FromTheVaultTransform_V17.json ignorado (menos de 40 cartas no mainBoard).
# Deck FromTheVaultTwenty_V13.json ignorado (menos de 40 cartas no mainBoard).
# Deck FullSleevesTheTattooPack_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Fun_With_Fungus.txt gerada com sucesso!
# Decklist Furious_Forces.txt gerada com sucesso!
# Decklist Fury.txt gerada com sucesso!
# Decklist Future_Shock.txt gerada com sucesso!
# Decklist Gabriel_Nassif_-_Blue-White_Anti-Affinity_Control.txt gerada com sucesso!
# Deck GandalfInThePelennorFields_LTC.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Garfield.txt gerada com sucesso!
# Decklist Garruk,_Savage_Herald.txt gerada com sucesso!
# Decklist Garruk.txt gerada com sucesso!
# Decklist Garruk.txt gerada com sucesso!
# Deck Garruk_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Gatecrasher.txt gerada com sucesso!
# Decklist George_Baxter,_Quarterfinalist.txt gerada com sucesso!
# Decklist Ghostly_Tide.txt gerada com sucesso!
# Decklist Gideon,_Martial_Paragon.txt gerada com sucesso!
# Decklist Gideon,_the_Oathsworn.txt gerada com sucesso!
# Decklist Gideon.txt gerada com sucesso!
# Decklist Gifts_of_the_Gods.txt gerada com sucesso!
# Deck Gigantic1_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Gigantic2_J22.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Gleeful_Flames.txt gerada com sucesso!
# Decklist Glorious_Combat.txt gerada com sucesso!
# Decklist Glorious_Combat.txt gerada com sucesso!
# Deck GoblinAndSquabblinFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck GoblinAndSquabblin_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Goblin_Assault.txt gerada com sucesso!
# Decklist Goblin_Fire.txt gerada com sucesso!
# Decklist Goblin_Mob.txt gerada com sucesso!
# Deck Goblins1_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Goblins1_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Goblins2_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Goblins2_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Goblins3_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Goblins3_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Goblins4_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Goblins4_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Goblins_Everywhere!.txt gerada com sucesso!
# Decklist Goblins.txt gerada com sucesso!
# Decklist Goblins.txt gerada com sucesso!
# Decklist Goblins.txt gerada com sucesso!
# Decklist Goblin_Warlord.txt gerada com sucesso!
# Decklist Going_Rogue.txt gerada com sucesso!
# Deck GoldDeck_7ED.json ignorado (menos de 40 cartas no mainBoard).
# Deck GoldDeck_8ED.json ignorado (menos de 40 cartas no mainBoard).
# Deck GoldDeck_9ED.json ignorado (menos de 40 cartas no mainBoard).
# Deck GoldPack_7ED.json ignorado (menos de 40 cartas no mainBoard).
# Deck GoldPack_8ED.json ignorado (menos de 40 cartas no mainBoard).
# Deck GoldPack_9ED.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Golgari_Deathcreep.txt gerada com sucesso!
# Decklist Golgari_Exploration.txt gerada com sucesso!
# Decklist Golgari_Growth.txt gerada com sucesso!
# Deck GolgariSwarm1_CLU.json ignorado (menos de 40 cartas no mainBoard).
# Deck GolgariSwarm2_CLU.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Golgari_Swarm.txt gerada com sucesso!
# Decklist Golgari.txt gerada com sucesso!
# Decklist Golgari.txt gerada com sucesso!
# Decklist Gondor_-_Green-White.txt gerada com sucesso!
# Deck GoToSchool1_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck GoToSchool2_J22.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Grab_for_Power.txt gerada com sucesso!
# Decklist Grand_Larceny.txt gerada com sucesso!
# Decklist Grave_Advantage.txt gerada com sucesso!
# Decklist Graveborn.txt gerada com sucesso!
# Decklist Grave_Danger.txt gerada com sucesso!
# Decklist Grave_Danger.txt gerada com sucesso!
# Decklist Grave_Matters.txt gerada com sucesso!
# Decklist Grave_Power.txt gerada com sucesso!
# Decklist Grave_Secrets.txt gerada com sucesso!
# Decklist Graveyard_Bash.txt gerada com sucesso!
# Decklist Graveyard_Overdrive_Collector's_Edition.txt gerada com sucesso!
# Decklist Graveyard_Overdrive.txt gerada com sucesso!
# Deck GreenAndWhiteHumans_KLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck GreenDeckA_10E.json ignorado (menos de 40 cartas no mainBoard).
# Deck GreenDeckA_M11.json ignorado (menos de 40 cartas no mainBoard).
# Deck GreenDeckA_M12.json ignorado (menos de 40 cartas no mainBoard).
# Deck GreenDeckB_10E.json ignorado (menos de 40 cartas no mainBoard).
# Deck GreenDeckB_M11.json ignorado (menos de 40 cartas no mainBoard).
# Deck GreenDeckB_M12.json ignorado (menos de 40 cartas no mainBoard).
# Deck GreenDeck_M14.json ignorado (menos de 40 cartas no mainBoard).
# Deck GreenDeck_M20.json ignorado (menos de 40 cartas no mainBoard).
# Deck GreenDeck_ORI.json ignorado (menos de 40 cartas no mainBoard).
# Deck GreenDeck_W16.json ignorado (menos de 40 cartas no mainBoard).
# Deck GreenSampleDeck_M13.json ignorado (menos de 40 cartas no mainBoard).
# Deck GreenSampleDeck_M15.json ignorado (menos de 40 cartas no mainBoard).
# Deck GreenWhiteAuras_ROE.json ignorado (menos de 40 cartas no mainBoard).
# Deck GreenWhiteConvoke_M15.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Green.txt gerada com sucesso!
# Deck Green_UND.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Grixis_Shambling_Army.txt gerada com sucesso!
# Decklist Grixis_Undead.txt gerada com sucesso!
# ...
# Deck TheDraculaLands_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist The_Flames_of_Rath.txt gerada com sucesso!
# Deck TheFulltextLandsFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck TheFulltextLands_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck TheGodzillaLandsFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist The_Hosts_of_Mordor.txt gerada com sucesso!
# Decklist The_Legion_of_Dusk.txt gerada com sucesso!
# Deck TheMeaningOfLifeMaybeFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck TheMeaningOfLifeMaybe_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck TheMightOfGaladriel_LTC.json ignorado (menos de 40 cartas no mainBoard).
# Decklist The_Nightstalkers.txt gerada com sucesso!
# Deck ThePathNotTraveledFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist The_Plague_-_Enchanced_Deck.txt gerada com sucesso!
# Decklist The_Plague.txt gerada com sucesso!
# Deck ThePrincessBrideFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ThePrincessBride_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist The_River_Heralds.txt gerada com sucesso!
# Deck TherosStargazingVolumeIFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck TherosStargazingVolumeIiFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck TherosStargazingVolumeIiiFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck TherosStargazingVolumeIvFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck TherosStargazingVolumeVFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist The_Ruinous_Powers_Collector's_Edition.txt gerada com sucesso!
# Decklist The_Ruinous_Powers.txt gerada com sucesso!
# Decklist The_Slivers_-_Advanced_Deck.txt gerada com sucesso!
# Decklist The_Slivers.txt gerada com sucesso!
# Deck TheSpaceBeyondTheStarsFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck TheSpaceBeyondTheStars_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist The_Sparkler_-_Advanced_Deck.txt gerada com sucesso!
# Decklist The_Sparkler.txt gerada com sucesso!
# Decklist The_Spikes_-_Advanced_Deck.txt gerada com sucesso!
# Decklist The_Spikes.txt gerada com sucesso!
# Deck TheStarsGazeBackFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck TheStarsGazeBack_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist The_Sun_Empire.txt gerada com sucesso!
# Decklist The_Swarm_-_Advanced_Deck.txt gerada com sucesso!
# Decklist The_Swarm.txt gerada com sucesso!
# Decklist The_Thought_Invoker.txt gerada com sucesso!
# Deck TheTokyoLandsEtched_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck TheTokyoLands_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck TheUnfathomableCrushingBrutalityOfBasicLandsFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck TheUnfathomableCrushingBrutalityOfBasicLands_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck TheWalkingDeadFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck TheWeirdestPetsInTheMultiverseFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck TheWeirdestPetsInTheMultiverse_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist The_Wilds_and_the_Deep.txt gerada com sucesso!
# Deck ThinkAgain1_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck ThinkAgain2_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck ThinkAgain3_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck ThinkAgain4_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck ThirdSeries_PVAN.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Thoughts_of_the_Wind.txt gerada com sucesso!
# Deck ThrillingTalesOfTheUndeadFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ThrillingTalesOfTheUndead_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Thrive_and_Thrash.txt gerada com sucesso!
# Decklist Tibalt.txt gerada com sucesso!
# Decklist Tidal_Mastery_-_Enhanced_Deck.txt gerada com sucesso!
# Decklist Tidal_Mastery.txt gerada com sucesso!
# Decklist Time_Curse.txt gerada com sucesso!
# Decklist Time_Drain_-_Enhanced_Deck.txt gerada com sucesso!
# Decklist Time_Drain.txt gerada com sucesso!
# Decklist Timeless_Wisdom.txt gerada com sucesso!
# Deck TimeTroubleTwoFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck TimeTroubleTwo_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Timey-Wimey.txt gerada com sucesso!
# Decklist Tinker_Time.txt gerada com sucesso!
# Deck Titanic1_BRO.json ignorado (menos de 40 cartas no mainBoard).
# Deck Titanic2_BRO.json ignorado (menos de 40 cartas no mainBoard).
# Decklist To_Adventure!.txt gerada com sucesso!
# Decklist Token_Triumph.txt gerada com sucesso!
# Decklist Tombstone_-_Enhanced_Deck.txt gerada com sucesso!
# Decklist Tombstone.txt gerada com sucesso!
# Decklist Tom_van_de_Logt_-_Machine_Head.txt gerada com sucesso!
# Decklist Tom_van_de_Logt_-_Replenish.txt gerada com sucesso!
# Deck TotallyMerciless_DMU.json ignorado (menos de 40 cartas no mainBoard).
# Deck TotallyRuthless_DMU.json ignorado (menos de 40 cartas no mainBoard).
# Deck TotallySpacedOutFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Totem_Power.txt gerada com sucesso!
# Deck Toxic1_ONE.json ignorado (menos de 40 cartas no mainBoard).
# Deck Toxic2_ONE.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Trample_Civilization_Underfoot.txt gerada com sucesso!
# Decklist Transference.txt gerada com sucesso!
# Deck TransformersOneShallStandOneShallFallFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck TransformersOneShallStandOneShallFall_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck TransformersOptimusPrimeVsMegatronFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck TransformersOptimusPrimeVsMegatron_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck TransformersRollOutOrRiseUpFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck TransformersRollOutOrRiseUp_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck Treasure1_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Treasure2_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Treasure3_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Treasure4_J22.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Treasure_Hunt.txt gerada com sucesso!
# Deck TreeHugging1_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck TreeHugging2_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck TreeHugging3_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck TreeHugging4_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Tricksy1_LTR.json ignorado (menos de 40 cartas no mainBoard).
# Deck Tricksy2_LTR.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Tricky_Terrain_Collector's_Edition.txt gerada com sucesso!
# Decklist Tricky_Terrain.txt gerada com sucesso!
# Decklist Troll_Shaman.txt gerada com sucesso!
# Decklist Trounce-O-Matic.txt gerada com sucesso!
# Decklist Truth_Seekers.txt gerada com sucesso!
# Decklist Turnabout.txt gerada com sucesso!
# Decklist Turnaround.txt gerada com sucesso!
# Decklist Tusk_Guardian.txt gerada com sucesso!
# Decklist Twisted_Reality.txt gerada com sucesso!
# Decklist Tyranid_Swarm_Collector's_Edition.txt gerada com sucesso!
# Decklist Tyranid_Swarm.txt gerada com sucesso!
# Decklist Ultimate_Sacrifice.txt gerada com sucesso!
# Decklist Undead_Knight.txt gerada com sucesso!
# Decklist Undead_Unleashed.txt gerada com sucesso!
# Deck UnderTheSea1_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck UnderTheSea2_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Underworld_Herald.txt gerada com sucesso!
# Deck Unearthed1_BRO.json ignorado (menos de 40 cartas no mainBoard).
# Deck Unearthed2_BRO.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Unearthed_Secrets.txt gerada com sucesso!
# Decklist Unflinching_Assault.txt gerada com sucesso!
# Deck Unicorns_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Decklist United_Assault.txt gerada com sucesso!
# Decklist Unlikely_Alliances.txt gerada com sucesso!
# Deck UnluckyThirteen_J22.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Unnatural_Forces.txt gerada com sucesso!
# Decklist Unnatural_Schemes.txt gerada com sucesso!
# Decklist Unraveling_Mind.txt gerada com sucesso!
# Decklist Unstable_Terrain.txt gerada com sucesso!
# Decklist Untamed_Wild.txt gerada com sucesso!
# Decklist Up_and_Away.txt gerada com sucesso!
# Decklist Upgrades_Unleashed.txt gerada com sucesso!
# Decklist Urza's_Iron_Alliance.txt gerada com sucesso!
# Deck UrzaS_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck ValentinesDay2021Foil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ValentinesDay2021_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Vampire_Lord.txt gerada com sucesso!
# Decklist Vampire_Onslaught.txt gerada com sucesso!
# Deck Vampires1_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Vampires2_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Vampires3_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Vampires4_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Vampires_MBS.json ignorado (menos de 40 cartas no mainBoard).
# Deck Vampires_ROE.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Vampiric_Bloodline.txt gerada com sucesso!
# Decklist Vampiric_Bloodlust.txt gerada com sucesso!
# Decklist Vampiric_Thirst.txt gerada com sucesso!
# Decklist Vehicle_Rush.txt gerada com sucesso!
# Deck Vehicles_J22.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Veloci-Ramp-Tor.txt gerada com sucesso!
# Decklist Venser.txt gerada com sucesso!
# Decklist Vicious_Cycle.txt gerada com sucesso!
# Decklist Virtue_and_Valor.txt gerada com sucesso!
# Decklist Vivien,_Nature's_Avenger.txt gerada com sucesso!
# Decklist Vivien's_Hunt.txt gerada com sucesso!
# Decklist Vivien.txt gerada com sucesso!
# Decklist Voracious_Rage.txt gerada com sucesso!
# Decklist Vraska,_Regal_Gorgon.txt gerada com sucesso!
# Decklist Vraska,_Scheming_Gorgon.txt gerada com sucesso!
# Decklist Vraska.txt gerada com sucesso!
# Decklist Wade_into_Battle.txt gerada com sucesso!
# Decklist Wade_into_Battle.txt gerada com sucesso!
# Decklist Waking_Nightmares.txt gerada com sucesso!
# Decklist Walk_the_Plank.txt gerada com sucesso!
# Deck Walls_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Warhammer40000OrksFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck Warhammer40000Orks_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck WarhammerAgeOfSigmarFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck WarhammerAgeOfSigmar_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Warlock.txt gerada com sucesso!
# Decklist War_Mage.txt gerada com sucesso!
# Decklist War_of_Attrition.txt gerada com sucesso!
# Decklist Warrior's_Code.txt gerada com sucesso!
# Decklist Way_of_the_Warrior.txt gerada com sucesso!
# Decklist Way_Wild.txt gerada com sucesso!
# Decklist Weapons_and_Wards.txt gerada com sucesso!
# Decklist We_Are_Legion.txt gerada com sucesso!
# Decklist Wei_Kingdom.txt gerada com sucesso!
# Deck WelcomeToCastleDraculaFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck WelcomeToCastleDracula_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck WelcomeToTheFungalFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck WelcomeToTheFungal_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck Welded1_BRO.json ignorado (menos de 40 cartas no mainBoard).
# Deck Welded2_BRO.json ignorado (menos de 40 cartas no mainBoard).
# Deck WellRead1_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck WellRead2_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck WellRead3_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck WellRead4_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Whirlpool.txt gerada com sucesso!
# Deck WhiteAndBlackSpirits_KLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck WhiteBlackLifeGain_M15.json ignorado (menos de 40 cartas no mainBoard).
# Deck WhiteBlueBestow_M15.json ignorado (menos de 40 cartas no mainBoard).
# Deck WhiteDeckA_10E.json ignorado (menos de 40 cartas no mainBoard).
# Deck WhiteDeckA_M11.json ignorado (menos de 40 cartas no mainBoard).
# Deck WhiteDeckA_M12.json ignorado (menos de 40 cartas no mainBoard).
# Deck WhiteDeckB_10E.json ignorado (menos de 40 cartas no mainBoard).
# Deck WhiteDeckB_M11.json ignorado (menos de 40 cartas no mainBoard).
# Deck WhiteDeckB_M12.json ignorado (menos de 40 cartas no mainBoard).
# Deck WhiteDeck_M14.json ignorado (menos de 40 cartas no mainBoard).
# Deck WhiteDeck_M20.json ignorado (menos de 40 cartas no mainBoard).
# Deck WhiteDeck_ORI.json ignorado (menos de 40 cartas no mainBoard).
# Deck WhiteDeck_W16.json ignorado (menos de 40 cartas no mainBoard).
# Deck WhiteEquipment_MBS.json ignorado (menos de 40 cartas no mainBoard).
# Deck WhiteGreenAura_MBS.json ignorado (menos de 40 cartas no mainBoard).
# Decklist White_Heat_-_Advanced_Deck.txt gerada com sucesso!
# Decklist White_Heat_-_Basic_Deck.txt gerada com sucesso!
# Deck WhiteSampleDeck_M13.json ignorado (menos de 40 cartas no mainBoard).
# Deck WhiteSampleDeck_M15.json ignorado (menos de 40 cartas no mainBoard).
# Deck WhiteWeenie_ROE.json ignorado (menos de 40 cartas no mainBoard).
# Decklist White.txt gerada com sucesso!
# Deck White_UND.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Wicked_Big.txt gerada com sucesso!
# Decklist Widowmaker_-_Advanced_Deck.txt gerada com sucesso!
# Decklist Widowmaker_-_Basic_Deck.txt gerada com sucesso!
# Decklist Wild_Bounty.txt gerada com sucesso!
# Decklist Wild-Eyed_Frenzy.txt gerada com sucesso!
# Decklist Wild_Rush.txt gerada com sucesso!
# Decklist Wild_Wizardry.txt gerada com sucesso!
# Decklist Will_Of_The_Masses.txt gerada com sucesso!
# Decklist Wing_and_Claw.txt gerada com sucesso!
# Decklist Winged_Stallion.txt gerada com sucesso!
# Deck Witchcraft1_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Witchcraft2_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Witch.txt gerada com sucesso!
# Decklist Witherbloom_Witchcraft.txt gerada com sucesso!
# Deck Wizards1_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Wizards2_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Wizards3_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck Wizards4_JMP.json ignorado (menos de 40 cartas no mainBoard).
# Deck WizardsOfTheStreetFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck WizardsOfTheStreet_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Wolfgang_Eder_-_Goblin_Bidding.txt gerada com sucesso!
# Deck Wolves1_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Wolves2_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Wolves3_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Wolves4_J22.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Woodland_Warriors.txt gerada com sucesso!
# Decklist World_Aflame.txt gerada com sucesso!
# Decklist Wrack_and_Rage.txt gerada com sucesso!
# Decklist Wrath_of_Mages.txt gerada com sucesso!
# Decklist Wrath_of_the_Mortals.txt gerada com sucesso!
# Decklist Wu_Kingdom.txt gerada com sucesso!
# Deck YearOfTheRatFoil_SLD.json ignorado (menos de 40 cartas no mainBoard).
# Deck ZakkSFirstDeck_ITP.json ignorado (menos de 40 cartas no mainBoard).
# Deck ZakkSFirstDeck_RQS.json ignorado (menos de 40 cartas no mainBoard).
# Deck ZakkSSecondDeck_ITP.json ignorado (menos de 40 cartas no mainBoard).
# Deck ZakkSSecondDeck_RQS.json ignorado (menos de 40 cartas no mainBoard).
# Deck ZendikarRisingWelcomeBooster_ZNR.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Zendikar's_Rage.txt gerada com sucesso!
# Decklist Zendikar.txt gerada com sucesso!
# Decklist Zombie_Empire.txt gerada com sucesso!
# Deck Zombies1_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Zombies2_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Zombies3_J22.json ignorado (menos de 40 cartas no mainBoard).
# Deck Zombies4_J22.json ignorado (menos de 40 cartas no mainBoard).
# Decklist Zombies_Unleashed.txt gerada com sucesso!
