# %%
# Importando a biblioteca mtgsdk
from mtgsdk import Set
from mtgsdk import Card

import pandas as pd

# %%
# Obtém todos os sets de Magic disponíveis
sets = Set.all()
# Cria uma lista de dicionários com os dados dos sets
sets_data = [{'Set Name': set.name, 'Code': set.code} for set in sets]
# Converte a lista de dicionários em um DataFrame do pandas
sets_df = pd.DataFrame(sets_data)
# Exibe o DataFrame
sets_df
# Out:
#                         Set Name  Code
# 0                  Tenth Edition   10E
# 1              Unlimited Edition   2ED
# 2            Double Masters 2022   2X2
# 3                 Double Masters   2XM
# 4       30th Anniversary Edition   30A
# ..                           ...   ...
# 768   Alchemy: Wilds of Eldraine  YWOE
# 769                     Zendikar   ZEN
# 770    Zendikar Rising Commander   ZNC
# 771  Zendikar Rising Expeditions   ZNE
# 772              Zendikar Rising   ZNR
#
# [773 rows x 2 columns]

# %%
# Lendo o set específico do senhor dos anéis
set_lotr = Set.find('LTR')

# %%
def show_set_properties(set_code):
    """
    Exibe todas as propriedades de um set específico baseado no código do set,
    apenas se o valor da propriedade não for None.
    
    Parâmetros:
        set_code (str): O código do set a ser lido.
    """
    # Busca o set pelo código
    set_obj = Set.find(set_code)
    
    if set_obj:
        properties = {
            'Code': set_obj.code,
            'Name': set_obj.name,
            'Gatherer Code': getattr(set_obj, 'gatherer_code', None),
            'Old Code': getattr(set_obj, 'old_code', None),
            'Magic Cards Info Code': getattr(set_obj, 'magic_cards_info_code', None),
            'Release Date': getattr(set_obj, 'release_date', None),
            'Border': getattr(set_obj, 'border', None),
            'Type': getattr(set_obj, 'type', None),
            'Block': getattr(set_obj, 'block', None),
            'Online Only': getattr(set_obj, 'online_only', None),
            'Booster': getattr(set_obj, 'booster', None),
            'MKM ID': getattr(set_obj, 'mkm_id', None),
            'MKM Name': getattr(set_obj, 'mkm_name', None)
        }
        
        # Filtra e imprime somente as propriedades que não são None
        for prop_name, prop_value in properties.items():
            if prop_value is not None:
                print(f"{prop_name}: {prop_value}")
    else:
        print("Set not found.")

# %%
show_set_properties('LTR')
# Out:
# Code: LTR
# Name: The Lord of the Rings: Tales of Middle-earth
# Release Date: 2023-06-23
# Type: draft_innovation
# Online Only: False

# %%
# Find all cards in LTR set
cards = Card.where(set="LTR").where(language="Portuguese (Brazil)").all()

# Quantos cards do Senhor dos Anéis existem em PT-BR?
print(len(cards))

# Como esses objetos são armazenados?
print(cards[0])
# Out:
# 856
# <mtgsdk.card.Card object at 0x0000013CE35A63F0>

# %%
# Looking for a specific card "Talento do Cuidador" Set "BLB"
# Parece que não temos atualização de BLB... Tem que ser edições mais antigas
cards = Card.where(set="BLB").all()
cards
# Out:
# [<mtgsdk.card.Card at 0x22a7eef5ca0>,
#  <mtgsdk.card.Card at 0x22a7ed85d60>,
#  <mtgsdk.card.Card at 0x22a7f2898e0>,
#  <mtgsdk.card.Card at 0x22a79bd8740>,
#  <mtgsdk.card.Card at 0x22a7f2ca270>,
#  <mtgsdk.card.Card at 0x22a7f2ca2a0>,
#  <mtgsdk.card.Card at 0x22a7f2ca2d0>,
#  <mtgsdk.card.Card at 0x22a7f2ca300>,
#  <mtgsdk.card.Card at 0x22a7f2ca330>,
#  <mtgsdk.card.Card at 0x22a7f2ca360>,
#  <mtgsdk.card.Card at 0x22a7f2ca390>,
#  <mtgsdk.card.Card at 0x22a7f2ca3c0>]

# %%
def show_card_properties(card):
    """
    Exibe todas as propriedades de um objeto Card específico,
    apenas se o valor da propriedade não for None.
    
    Parâmetros:
        card (Card): O objeto Card cujas propriedades serão lidas.
    """
    if card:
        properties = {
            'Name': card.name,
            'Multiverse ID': getattr(card, 'multiverse_id', None),
            'Layout': getattr(card, 'layout', None),
            'Names': getattr(card, 'names', None),
            'Mana Cost': getattr(card, 'mana_cost', None),
            'CMC': getattr(card, 'cmc', None),
            'Colors': getattr(card, 'colors', None),
            'Color Identity': getattr(card, 'color_identity', None),
            'Type': getattr(card, 'type', None),
            'Supertypes': getattr(card, 'supertypes', None),
            'Subtypes': getattr(card, 'subtypes', None),
            'Rarity': getattr(card, 'rarity', None),
            'Text': getattr(card, 'text', None),
            'Flavor': getattr(card, 'flavor', None),
            'Artist': getattr(card, 'artist', None),
            'Number': getattr(card, 'number', None),
            'Power': getattr(card, 'power', None),
            'Toughness': getattr(card, 'toughness', None),
            'Loyalty': getattr(card, 'loyalty', None),
            'Variations': getattr(card, 'variations', None),
            'Watermark': getattr(card, 'watermark', None),
            'Border': getattr(card, 'border', None),
            'Timeshifted': getattr(card, 'timeshifted', None),
            'Hand': getattr(card, 'hand', None),
            'Life': getattr(card, 'life', None),
            'Reserved': getattr(card, 'reserved', None),
            'Release Date': getattr(card, 'release_date', None),
            'Starter': getattr(card, 'starter', None),
            'Rulings': getattr(card, 'rulings', None),
            'Foreign Names': getattr(card, 'foreign_names', None),
            'Printings': getattr(card, 'printings', None),
            'Original Text': getattr(card, 'original_text', None),
            'Original Type': getattr(card, 'original_type', None),
            'Legalities': getattr(card, 'legalities', None),
            'Source': getattr(card, 'source', None),
            'Image URL': getattr(card, 'image_url', None),
            'Set': getattr(card, 'set', None),
            'Set Name': getattr(card, 'set_name', None),
            'ID': getattr(card, 'id', None)
        }
        
        # Filtra e imprime somente as propriedades que não são None
        for prop_name, prop_value in properties.items():
            if prop_value is not None:
                print(f"{prop_name}: {prop_value}")
    else:
        print("Card not found.")

# %%
# Vendo um card aleatório
show_card_properties(cards[60])
# Out:
# Name: Lórien Revealed
# Multiverse ID: 616890
# Layout: normal
# Mana Cost: {3}{U}{U}
# CMC: 5.0
# Colors: ['U']
# Color Identity: ['U']
# Type: Sorcery
# Rarity: Common
# Text: Draw three cards.
# Islandcycling {1} ({1}, Discard this card: Search your library for an Island card, reveal it, put it into your hand, then shuffle.)
# Flavor: "Look on us now with friendly eyes! Behold the trees of the Naith of Lórien and be glad!"
# —Haldir
# Artist: Randy Gallegos
# Number: 60
# Variations: ['50fb445a-ce74-5979-9f96-4e45385eeea1']
# Rulings: [{'date': '2023-06-16', 'text': 'Typecycling is a form of cycling. Any ability that triggers on a card being cycled also triggers on a card being typecycled. Any ability that stops a cycling ability from being activated also stops a typecycling ability from being activated.'}, {'date': '2023-06-16', 'text': "Unlike the normal cycling ability, typecycling doesn't allow you to draw a card. Rather, it lets you search your library for a card with the type or types indicated by the ability name. For example, a card with basic landcycling lets you search for a basic land card, and a card with Wizardcycling lets you search for a Wizard card."}]
# Foreign Names: [{'name': 'Offenbarungen in Lórien', 'text': 'Ziehe drei Karten.\nInselumwandlung {1} ({1}, wirf diese Karte ab: Durchsuche deine Bibliothek nach einer Insel-Karte, zeige sie offen vor, nimm sie auf deine Hand und mische danach.)', 'type': 'Hexerei', 'flavor': '„Betrachtet uns nun freundlichen Auges! Erblickt die Bäume des Naith von Lórien und frohlockt!"\n—Haldir', 'imageUrl': 'http://gatherer.wizards.com/Handlers/Image.ashx?multiverseid=617151&type=card', 'language': 'German', 'identifiers': {'scryfallId': 'f3f17f6d-972c-4450-868d-433d49b30bb7', 'multiverseId': 617151}, 'multiverseid': 617151}, {'name': 'Lórien revelado', 'text': 'Roba tres cartas.\nCiclo de isla {1}. ({1}, descartar esta carta: Busca en tu biblioteca una carta de Isla, muéstrala, ponla en tu mano y luego baraja.)', 'type': 'Conjuro', 'flavor': '"¡Ya puedes mirarnos con ojos amistosos! ¡Contempla los árboles del naith de Lórien y regocíjate!".\n—Haldir', 'imageUrl': 'http://gatherer.wizards.com/Handlers/Image.ashx?multiverseid=617412&type=card', 'language': 'Spanish', 'identifiers': {'scryfallId': 'ec017968-b23b-4aa6-9072-24f2b497ebed', 'multiverseId': 617412}, 'multiverseid': 617412}, {'name': 'La Lórien révélée', 'text': "Piochez trois cartes.\nRecyclage d'île {1} ({1}, défaussez-vous de cette carte : Cherchez dans votre bibliothèque une carte d'île, révélez-la, mettez-la dans votre main, puis mélangez.)", 'type': 'Rituel', 'flavor': '« Posez désormais sur nous un regard amical ! Admirez les arbres du Naith de Lórien et soyez heureux ! »\n—Haldir', 'imageUrl': 'http://gatherer.wizards.com/Handlers/Image.ashx?multiverseid=617673&type=card', 'language': 'French', 'identifiers': {'scryfallId': 'ffea6587-73c1-43de-8608-34cf6224b576', 'multiverseId': 617673}, 'multiverseid': 617673}, {'name': 'Lórien Rivelata', 'text': 'Pesca tre carte.\nCicloisola {1} ({1}, Scarta questa carta: Passa in rassegna il tuo grimorio per una carta Isola, rivelala e aggiungila alla tua mano, poi rimescola.)', 'type': 'Stregoneria', 'flavor': '"Guardateci ora con occhi amici! Ammirate gli alberi del Naith di Lórien e allietatevi!"\n—Haldir', 'imageUrl': 'http://gatherer.wizards.com/Handlers/Image.ashx?multiverseid=617934&type=card', 'language': 'Italian', 'identifiers': {'scryfallId': 'f7fb618b-e5c6-483d-870f-9a901b3189cd', 'multiverseId': 617934}, 'multiverseid': 617934}, {'name': 'ロリアンの発見', 'text': 'カード３枚を引く。\n島サイクリング{1} （{1}, このカードを捨てる：あなたのライブラリーから島・カード１枚を探す。それを公開し、あなたの手札に加える。その後、ライブラリーを切り直す。）', 'type': 'ソーサリー', 'flavor': '「友を見る目で我らを見よ！ロリアンのナイスの木々を眺め、歓喜せよ！」\n――ハルディア', 'imageUrl': 'http://gatherer.wizards.com/Handlers/Image.ashx?multiverseid=618195&type=card', 'language': 'Japanese', 'identifiers': {'scryfallId': 'ade25f37-aa15-402a-b9f6-f6bb43b0c9d4', 'multiverseId': 618195}, 'multiverseid': 618195}, {'name': 'Lórien Revelada', 'text': 'Compre três cards.\nReciclar Ilha {1} ({1}, descarte este card: Procure em seu grimório um card de Ilha, revele-o, coloque-o em sua mão e depois embaralhe.)', 'type': 'Feitiço', 'flavor': '"Agora nos olhe com olhos amistosos! Contemple as árvores do Naith de Lórien e alegre-se!"\n— Haldir', 'imageUrl': 'http://gatherer.wizards.com/Handlers/Image.ashx?multiverseid=618456&type=card', 'language': 'Portuguese (Brazil)', 'identifiers': {'scryfallId': '2f066996-2f59-4004-993a-b4098e69d751', 'multiverseId': 618456}, 'multiverseid': 618456}, {'name': '揭现罗瑞恩', 'text': '抓三张牌。\n循环海岛{1}（{1}，弃掉此牌：从你的牌库中搜寻一张海岛牌，展示该牌，将它置于你手上，然后洗牌。）', 'type': '法术', 'flavor': '「现在请用友善的眼光来看待我们！敬请见证罗瑞恩耐斯森林，开心感受吧！」\n～哈尔迪尔', 'imageUrl': 'http://gatherer.wizards.com/Handlers/Image.ashx?multiverseid=618717&type=card', 'language': 'Chinese Simplified', 'identifiers': {'scryfallId': '0ba5a9ff-99b5-4fda-9dca-7ca1b8fdf454', 'multiverseId': 618717}, 'multiverseid': 618717}]
# Printings: ['LTR']
# Original Text: Draw three cards.
# Islandcycling {1} ({1}, Discard this card: Search your library for an Island card, reveal it, put it into your hand, then shuffle.)
# Original Type: Sorcery
# Legalities: [{'format': 'Alchemy', 'legality': 'Legal'}, {'format': 'Brawl', 'legality': 'Legal'}, {'format': 'Commander', 'legality': 'Legal'}, {'format': 'Duel', 'legality': 'Legal'}, {'format': 'Gladiator', 'legality': 'Legal'}, {'format': 'Historic', 'legality': 'Legal'}, {'format': 'Legacy', 'legality': 'Legal'}, {'format': 'Modern', 'legality': 'Legal'}, {'format': 'Oathbreaker', 'legality': 'Legal'}, {'format': 'Pauper', 'legality': 'Legal'}, {'format': 'Paupercommander', 'legality': 'Legal'}, {'format': 'Timeless', 'legality': 'Legal'}, {'format': 'Vintage', 'legality': 'Legal'}]
# Image URL: http://gatherer.wizards.com/Handlers/Image.ashx?multiverseid=616890&type=card
# Set: LTR
# Set Name: The Lord of the Rings: Tales of Middle-earth
# ID: 74668c89-536f-51a2-802c-d96904a83eb9

# %%
# Vendo todos os tipos de cards do set
types = set()
for card in cards:
    if card.type:  # Verifica se o card possui um tipo
        types.add(card.type)

# Exiba os tipos únicos
print("Tipos únicos no Set:")
for t in sorted(types):
    print(t)
# Out:
# Tipos únicos no Set:
# Artifact
# Artifact Creature — Scarecrow
# Artifact Creature — Wall
# Artifact — Equipment
# Artifact — Food
# Basic Land — Forest
# Basic Land — Island
# Basic Land — Mountain
# Basic Land — Plains
# Basic Land — Swamp
# Creature — Bat
# Creature — Beast
# Creature — Bird
# Creature — Bird Horror
# Creature — Bird Soldier
# Creature — Dog
# Creature — Drake Beast
# Creature — Dwarf
# Creature — Dwarf Artificer
# Creature — Dwarf Soldier
# Creature — Elemental
# Creature — Elephant
# Creature — Elf Druid
# Creature — Elf Pilot
# Creature — Elf Scout
# Creature — Elf Warrior
# Creature — Goblin Warrior
# Creature — Halfling Citizen
# Creature — Halfling Peasant
# Creature — Halfling Soldier
# Creature — Human Knight
# Creature — Human Peasant
# Creature — Human Pirate
# Creature — Human Ranger
# Creature — Human Shaman
# Creature — Human Soldier
# Creature — Human Warrior
# Creature — Nightmare Elf
# Creature — Orc Archer
# Creature — Orc Berserker
# Creature — Orc Soldier
# Creature — Orc Warrior
# Creature — Spider
# Creature — Spirit Soldier
# Creature — Treefolk
# Creature — Troll
# Creature — Troll Soldier
# Creature — Wolf
# Creature — Wraith Knight
# Enchantment
# Enchantment — Aura
# Enchantment — Saga
# Instant
# Land
# Legendary Artifact
# Legendary Artifact — Equipment
# Legendary Artifact — Vehicle
# Legendary Creature — Avatar Demon
# Legendary Creature — Avatar Horror
# Legendary Creature — Avatar Rogue
# Legendary Creature — Avatar Wizard
# Legendary Creature — Bird Noble
# Legendary Creature — Bird Soldier
# Legendary Creature — Dwarf Advisor
# Legendary Creature — Dwarf Warrior
# Legendary Creature — Elf Archer
# Legendary Creature — Elf Noble
# Legendary Creature — Goblin Soldier
# Legendary Creature — God Bard
# Legendary Creature — Halfling Citizen
# Legendary Creature — Halfling Horror
# Legendary Creature — Halfling Knight
# Legendary Creature — Halfling Peasant
# Legendary Creature — Halfling Rogue
# Legendary Creature — Halfling Scout
# Legendary Creature — Halfling Soldier
# Legendary Creature — Halfling Warrior
# Legendary Creature — Horse
# Legendary Creature — Human Advisor
# Legendary Creature — Human Cleric
# Legendary Creature — Human Elf Noble
# Legendary Creature — Human Knight
# Legendary Creature — Human Noble
# Legendary Creature — Human Peasant
# Legendary Creature — Human Ranger
# Legendary Creature — Human Rogue
# Legendary Creature — Human Soldier
# Legendary Creature — Kraken
# Legendary Creature — Nymph
# Legendary Creature — Orc Soldier
# Legendary Creature — Spider Demon
# Legendary Creature — Spirit Noble
# Legendary Creature — Treefolk
# Legendary Creature — Wraith Noble
# Legendary Enchantment
# Legendary Instant
# Legendary Land
# Sorcery

# %%
# Ideia: Objeto do Tipo Deck
# Criei uma classe para representar um deck de Magic

import os
notebook_path = os.getcwd()
project_path = "c:\\Users\\gufer\\OneDrive\\Documentos\\FIAP\\Fase_03"
os.chdir(project_path)
from deck import Deck
os.chdir(notebook_path)
